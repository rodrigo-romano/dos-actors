# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
data0 = pd.read_parquet("data_baseline.parquet")
print(data0.columns)
fig,axs = plt.subplots(nrows=2, sharex=True,figsize=(15,15))
ax = axs[0]
ax.plot(np.vstack(data0["OSSM1Lcl"]))
ax.grid()
ax = axs[1]
ax.plot(np.vstack(data0["MCM2Lcl6D"]))
ax.grid()
# Out:
# Index(['MountEncoders', 'OSSM1Lcl', 'MCM2Lcl6D'], dtype='object')

# %%
data = pd.read_parquet("data.parquet")
print(data.columns)
fig,axs = plt.subplots(nrows=2, sharex=True,figsize=(15,15))
ax = axs[0]
ax.plot(np.vstack(data["OSSM1Lcl"]))
ax.grid()
#ax.set_ylim(np.asarray([-1,1])*1e-1)
ax = axs[1]
ax.plot(np.vstack(data["MCM2Lcl6D"]))
ax.grid()
#ax.set_ylim(np.asarray([-1, 1])*1e-1)
# Out:
# Index(['MountEncoders', 'OSSM1Lcl', 'MCM2Lcl6D'], dtype='object')

# %%
plt.plot(np.vstack(data0["MountEncoders"]))
plt.ylim(np.asarray([-1,1])*1e-4)
# Out:
# (-0.0001, 0.0001)

# %%
plt.plot(np.vstack(data["MountEncoders"]))
plt.ylim(np.asarray([-1,1])*1e-4)
# Out:
# (-0.0001, 0.0001)

# %%
plt.plot(np.vstack(data["MountEncoders"]))
plt.ylim(np.asarray([-1,1])*1e-4)
# Out:
# (-0.0001, 0.0001)
