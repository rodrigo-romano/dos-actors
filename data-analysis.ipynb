# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("dark_background")

# %%
data = pd.read_parquet("m2_logs.parquet")
data.columns
# Out:
# Index(['MCM2Lcl6D'], dtype='object')

# %%
t = np.arange(len(data))/8e3
fig, ax = plt.subplots()
ax.plot(t, np.vstack(data["MCM2Lcl6D"])[:,:6])
ax.grid()
ax.set_xlabel("Time[s]")
ax.set_ylabel("MCM2Lcl6D")
#ax.set_xlim([0,1e-1])
# Out:
# Text(0, 0.5, 'MCM2Lcl6D')

# %%
data = pd.read_parquet("setpoint_mount.parquet")
data.columns
# Out:
# Index(['MountEncoders', 'OSSM1Lcl', 'MCM2Lcl6D'], dtype='object')

# %%
np.vstack(data["MountEncoders"]).shape
# Out:
# (30000, 14)

# %%
n = 2900
t = np.arange(n)*1e-3

# %%
fig,ax = plt.subplots()
ax.plot(t,np.vstack(data["MountEncoders"])[:n,:]);
ax.grid()
ax.set_xlabel("Time[s]")
ax.set_ylabel("Mount encoders")
# Out:
# Text(0, 0.5, 'Mount encoders')

# %%
fig,ax = plt.subplots()
ax.plot(t,np.vstack(data["MountEncoders"])[:10000,:]);
ax.grid()
ax.set_xlabel("Time[s]")
ax.set_ylabel("Mount encoders")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-abbc31b80f2e> in <module>()
#       1 fig,ax = plt.subplots()
# ----> 2 ax.plot(t,np.vstack(data["MountEncoders"])[:10000,:]);
#       3 ax.grid()
#       4 ax.set_xlabel("Time[s]")
#       5 ax.set_ylabel("Mount encoders")
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (3000,) and (10000, 14)

# %%
fig,axs = plt.subplots(nrows=2,sharex=True,figsize=(10,10))
ax = axs[0]
ax.plot(np.vstaack(data["OSSM1Lcl"]));
ax.grid()a
ax = axs[1]
ax.plot(np.vstack(data["MCM2Lcl6D"]))
ax.grid()

# %%
data = pd.read_parquet("setpoint-mount-m1-m2-tt.parquet")
data.columns
# Out:
# Index(['OSSM1Lcl', 'MCM2Lcl6D'], dtype='object')

# %%
plt.style.use("dark_background")
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(10, 10))
ax = axs[0]
ax.plot(np.vstack(data["OSSM1Lcl"]))
ax.grid()
ax = axs[1]
ax.plot(np.vstack(data["MCM2Lcl6D"]))
ax.grid()

# %%
data = pd.read_parquet("tt_feedback.parquet")
data.columns
# Out:
# Index(['TTFB'], dtype='object')

# %%
plt.plot(np.vstack(data["TTFB"]))
plt.grid()

# %%
poke = np.load("poke_mat.pkl",allow_pickle=True)

# %%
np.asarray(poke[0]).sum()
# Out:
# 0.4988821187389875

# %%
np.asarray(poke[1]).sum()
# Out:
# 18.918380108784437
