# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_parquet("ngao.parquet")
df
# Out:
#                         WfeRms  \
# 0     [1.1363295016053598e-06]
# 1     [1.1363422345311847e-06]
# 2     [1.1654683476081118e-06]
# 3     [1.1654810805339366e-06]
# 4     [1.2287538311284152e-06]
# ...                        ...
# 7995                     [nan]
# 7996                     [nan]
# 7997                     [nan]
# 7998                     [nan]
# 7999                     [nan]
#
#                                           SegmentWfeRms  \
# 0     [8.939039162214613e-07, 1.0549617854849203e-06...
# 1     [8.936619906307897e-07, 1.0548468480919837e-06...
# 2     [9.228392059412727e-07, 1.0909233196798596e-06...
# 3     [9.22594438179658e-07, 1.0908037211265764e-06,...
# 4     [9.842243571256404e-07, 1.1660962400128483e-06...
# ...                                                 ...
# 7995                [nan, nan, nan, nan, nan, nan, nan]
# 7996                [nan, nan, nan, nan, nan, nan, nan]
# 7997                [nan, nan, nan, nan, nan, nan, nan]
# 7998                [nan, nan, nan, nan, nan, nan, nan]
# 7999                [nan, nan, nan, nan, nan, nan, nan]
#
#                                           SegmentPiston
# 0     [-2.02660089598794e-06, -1.635867306504224e-06...
# 1     [-2.0269505967007717e-06, -1.6355883190044551e...
# 2     [-2.0028467133670347e-06, -1.6291079418806476e...
# 3     [-2.0032020984217525e-06, -1.628839072509436e-...
# 4     [-1.9812196114799008e-06, -1.622232275622082e-...
# ...                                                 ...
# 7995                [nan, nan, nan, nan, nan, nan, nan]
# 7996                [nan, nan, nan, nan, nan, nan, nan]
# 7997                [nan, nan, nan, nan, nan, nan, nan]
# 7998                [nan, nan, nan, nan, nan, nan, nan]
# 7999                [nan, nan, nan, nan, nan, nan, nan]
#
# [8000 rows x 3 columns]

# %%
t = np.arange(df.shape[0])/8000
seg_piston = np.vstack(df["SegmentPiston"])*1e9
wfe_rms = np.vstack(df["WfeRms"])*1e9
seg_wfe_rms = np.vstack(df["SegmentWfeRms"])*1e9

# %%
fig,ax = plt.subplots()
ax.plot(t,seg_piston)
ax.legend(range(1,8))
ax.fill_between(t,-380,380,color="C3",alpha=0.2)
ax.fill_between(t, -0.375 * 760, 0.375 * 760, color="C3", alpha=0.2)
ax.grid()
ax.set_xticks(np.arange(0,1,0.1))
ax.set_yticks(np.arange(-4,5)*380)
ax.set_xlabel("Time [s]")
ax.set_ylabel("Segment piston [nm]")

#ax.set_xlim(0, 0.2)
#ax.set_ylim(-50,50)
# Out:
# Text(0, 0.5, 'Segment piston [nm]')

# %%
fig,ax = plt.subplots()
ax.plot(t,seg_piston)
ax.legend(range(1,8))
ax.fill_between(t,-380,380,color="C3",alpha=0.2)
ax.fill_between(t, -0.375 * 760, 0.375 * 760, color="C3", alpha=0.2)
ax.grid()
ax.set_xticks(np.arange(0,1,0.1))
ax.set_yticks(np.arange(-4,5)*380)
ax.set_xlabel("Time [s]")
ax.set_ylabel("Segment piston [nm]")

ax.set_xlim(0, 0.4)
ax.set_ylim(-2000,2000)
# Out:
# (-2000.0, 2000.0)

# %% [markdown]
# fig,ax = plt.subplots()
# ax.plot(t,seg_piston,'.-')
# ax.grid()
# ax.set_xlim(1-0.01,1)
# ax.set_ylim(-20,20)
# ax.set_xticks(np.arange(0.99,1,1e-3));

# %%
fig, ax = plt.subplots()
ax.plot(t, seg_wfe_rms)
ax.legend(range(1, 8))
ax.plot(t, wfe_rms,"k")
ax.grid()
ax.set_xlabel("Time [s]")
ax.set_ylabel("Segment Wfe RMS [nm]")
ax.set_ylim([0,500])
ax.set_xticks(np.arange(0,1,0.1));
