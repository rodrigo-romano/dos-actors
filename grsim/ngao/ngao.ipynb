# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_parquet("ngao.parquet")
df
# Out:
#                         WfeRms  \
# 0     [1.1363295016053598e-06]
# 1     [1.1363422345311847e-06]
# 2     [1.1363540579623077e-06]
# 3     [1.1363677003828343e-06]
# 4     [1.1363781595719047e-06]
# ...                        ...
# 7995  [1.1604371508155964e-07]
# 7996  [1.1636314667384795e-07]
# 7997  [1.1669608568354306e-07]
# 7998  [1.1704334212936374e-07]
# 7999  [1.1740815608618504e-07]
#
#                                           SegmentWfeRms  \
# 0     [8.939039162214613e-07, 1.0549617854849203e-06...
# 1     [8.936619906307897e-07, 1.0548468480919837e-06...
# 2     [8.93416824965243e-07, 1.0547267947913497e-06,...
# 3     [8.931722845773038e-07, 1.0546021940172068e-06...
# 4     [8.929235377763689e-07, 1.0544844144533272e-06...
# ...                                                 ...
# 7995  [1.0523390159278279e-07, 1.0184047738448498e-0...
# 7996  [1.0549081963517892e-07, 1.0222530733017265e-0...
# 7997  [1.0576233933079493e-07, 1.0263637051366459e-0...
# 7998  [1.060465351088169e-07, 1.0306317221875361e-07...
# 7999  [1.0634419567168152e-07, 1.0349889834060377e-0...
#
#                                           SegmentPiston
# 0     [-2.02660089598794e-06, -1.635867306504224e-06...
# 1     [-2.0269505967007717e-06, -1.6355883190044551e...
# 2     [-2.027310756602674e-06, -1.6353104683730635e-...
# 3     [-2.0276759187254356e-06, -1.6350402347597992e...
# 4     [-2.0280369881220395e-06, -1.6347637483704602e...
# ...                                                 ...
# 7995  [7.661171141926104e-10, 7.666780987847233e-09,...
# 7996  [8.496248704581433e-10, 8.185601529930864e-09,...
# 7997  [9.296679537307284e-10, 8.698584075261806e-09,...
# 7998  [1.0080026813241716e-09, 9.2163299214576e-09, ...
# 7999  [1.0891637591825543e-09, 9.73444524987599e-09,...
#
# [8000 rows x 3 columns]

# %%
t = np.arange(df.shape[0])/8000
seg_piston = np.vstack(df["SegmentPiston"])*1e9
wfe_rms = np.vstack(df["WfeRms"])*1e9
seg_wfe_rms = np.vstack(df["SegmentWfeRms"])*1e9

# %%
fig,ax = plt.subplots()
ax.plot(t,seg_piston)
ax.legend(range(1,8))
ax.fill_between(t,-380,380,color="C3",alpha=0.2)
ax.fill_between(t, -190, 190, color="C3", alpha=0.2)
ax.grid()
ax.set_xlabel("Time [s]")
ax.set_ylabel("Segment piston [nm]")

#ax.set_xlim(0, 0.2)
#ax.set_ylim(-50,50)
# Out:
# Text(0, 0.5, 'Segment piston [nm]')

# %%
fig,ax = plt.subplots()
ax.plot(t,seg_piston,'.-')
ax.grid()
ax.set_xlim(1-0.01,1)
ax.set_ylim(-20,20)
ax.set_xticks(np.arange(0.99,1,1e-3));

# %%
fig, ax = plt.subplots()
ax.plot(t, seg_wfe_rms)
ax.legend(range(1, 8))
ax.plot(t, wfe_rms,"k")
ax.grid()
ax.set_xlabel("Time [s]")
ax.set_ylabel("Segment Wfe RMS [nm]")
ax.set_ylim([0,500])
# Out:
# (0.0, 500.0)
