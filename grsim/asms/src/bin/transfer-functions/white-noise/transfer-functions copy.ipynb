# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import welch
#plt.style.use('dark_background')
# %matplotlib inline

# %%
df = pd.read_parquet("data.parquet")
df
# Out:
#                                U                          Y
# 0        [1.206033293888201e-08]    [8.727482428817559e-11]
# 1      [-2.1947891758306664e-08]   [2.1055440700705376e-10]
# 2         [3.45197509121029e-07]    [2.113260354072572e-09]
# 3       [3.8130061856346446e-08]   [1.0452832838943687e-08]
# 4        [3.596979461035628e-08]    [9.706380421569952e-09]
# ...                          ...                        ...
# 80995    [6.725145679977573e-08]   [-6.507559679014109e+50]
# 80996   [1.7972614339060257e-07]  [-6.0648076964888095e+50]
# 80997    [1.241570667580078e-07]   [-5.592765452353602e+50]
# 80998   [1.0215576944358348e-07]   [-5.093494847253265e+50]
# 80999   [2.8233363635298502e-08]   [-4.569189535762591e+50]
#
# [81000 rows x 2 columns]

# %%
t = 1e3*np.arange(df.shape[0]-1000)/8000
u = np.vstack(df["U"])[1000:]
y = np.vstack(df["Y"])[1000:]

# %%
fig,ax = plt.subplots()
ax.plot(u,alpha=0.5,label="U")
ax.plot(y,alpha=0.5,label="Y")
ax.grid()
#ax.set_xlabel('Time [s]')
ax.legend()
ax.set_ylim(np.asarray([-1,1])*1e-6)
#ax.set_xlim([0,2000])
# Out:
# (-1e-06, 1e-06)

# %%
nu.shape,psd_u.shape
# Out:
# ((1001,), (6, 1001))

# %%
nu,psd_u = welch(u.T,fs=8000, nperseg=1000*4)
nu,psd_y = welch(y.T,fs=8000, nperseg=1000*4)
tf_db = 10*np.log10(psd_y/psd_u).T

# %%
#np.savez("ASMS_TF.npz",nu=nu,tf_db=tf_db)

# %%
fig,ax = plt.subplots()
ax.loglog(nu,psd_u.T,label="U")
ax.loglog(nu,psd_y.T,label="Y")
ax.grid()
ax.set_xlabel('Frequency [Hz]')
ax.legend()

# %%
10*np.log10(0.125)
# Out:
# -9.030899869919436

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db,"C0,",alpha=0.05)
ax.grid(which='both',alpha=0.25)
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("ASM#1 KL mode PSDs [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
ax.set_yticks([-20,-15,-10,-3,0,-6,6,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db,"C0",alpha=0.05)
ax.grid(which='both',alpha=0.25)
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
ax.set_yticks([-20,-15,-10,-3,-6,6,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,:66],"C0",alpha=0.25)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
n = 25
(n+1)*(n+2)/2
# Out:
# 351.0

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,66:231],"C0",alpha=0.5)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,231:351],"C0",alpha=0.5)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,351:],"C0",alpha=0.5)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,347],"C0",alpha=0.5)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,416:418],"C0",alpha=0.5)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
#ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,:6])
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,10*np.log10(psd_y/psd_u).T)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
ax.legend(list(range(1,psd_u.shape[0]+1)))
ax.fill_between([10,800],[-3, -3],6,color="C3",alpha=0.3)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,0],label="piston")
ax.semilogx(nu,tf_db[:,5],label="focus")
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
ax.legend()
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,tf_db[:,1])
ax.semilogx(nu,tf_db[:,2])
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
ax.fill_between([10,4e3],[-3, -3],6,color="C1",alpha=0.25)
ax.fill_between([800,4e3],[-20, -20],-3,color="C1",alpha=0.25)

# %%
fig,ax = plt.subplots()
ax.semilogx(nu,10*np.log10(psd_y/psd_u))
ax.fill_between([10,800],[-3, -3],6,color="C3",alpha=0.3)
ax.grid(which='both')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel("PSD [dB]")
ax.set_xlim([10,4e3])
ax.set_ylim([-20,10])
# Out:
# (-20.0, 10.0)

# %%
nu[1]
# Out:
# 2.0

# %%
8000/2000
# Out:
# 4.0

# %%
80000/2000
# Out:
# 40.0

# %%
18**2/2,17*18/2
# Out:
# (162.0, 153.0)

# %%
8*9/2
# Out:
# 36.0
