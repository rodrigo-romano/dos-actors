# %%
import numpy as np
import matplotlib.pyplot as plt
from structure_function import Data,StructureFunctionSample
plt.style.use("dark_background")

# %%
ls ..
# Out:
# Cargo.lock
# Cargo.toml
# Dockerfile
# Makefile
# PSSnFwhmDomeSeeing.pkl
# PSSnFwhmDomeSeeing_free-atmosphere.pkl
# atm-sf.bin
# atmosphere_opd.bin
# data/
# data-analysis.ipynb
# data.parquet
# domeseeing.yaml
# examples/
# integrated_model.dot
# integrated_model.dot.svg
# kl_var.pkl
# opds.pkl
# pssn-fwhm_domeseeing.parquet
# pssn-fwhm_domeseeing_free-atmosphere.parquet
# sf-1st_mean.pkl
# sf-atm.pkl
# sf.pkl
# sf0-fit.png
# sf_mean.pkl
# sfpy/
# src/
# stats_domeseeing.parquet

# %%
with open("../atm-sf.bin", "rb") as f:
    data = Data.bincode_deserialize(f.read())
# Out:
# ---------------------------------------------------------------------------
# DeserializationError                      Traceback (most recent call last)
# <ipython-input-2-b45711b2c6c6> in <module>()
#       1 with open("../atm-sf.bin", "rb") as f:
# ----> 2     data = Data.bincode_deserialize(f.read())
#
# ~/projects/dos-actors/clients/domeseeing/analysis/sfpy/structure_function/__init__.py in bincode_deserialize(input)
#      14     @staticmethod
#      15     def bincode_deserialize(input: bytes) -> 'Data':
# ---> 16         v, buffer = bincode.deserialize(input, Data)
#      17         if buffer:
#      18             raise st.DeserializationError("Some input bytes were not read");
#
# ~/projects/dos-actors/clients/domeseeing/analysis/sfpy/bincode/__init__.py in deserialize(content, obj_type)
#      74 def deserialize(content: bytes, obj_type) -> typing.Tuple[typing.Any, bytes]:
#      75     deserializer = BincodeDeserializer(content)
# ...

# %%
data = np.load("../atm-sf.pkl",allow_pickle=True)
len(data)
# Out:
# 100

# %%
fig, ax = plt.subplots()
for i in [0,10,50]:
    b = [x['baseline'] for x in data[i]['sf']]
    sf = [x['value'] for x in data[i]['sf']]
    ax.plot(b,sf,'.',alpha=0.1)

# %%
fig, ax = plt.subplots()
for i in [0,10,50]:
    b = [x['baseline'] for x in data[i]['sf']]
    sf = [x['value'] for x in data[i]['sf']]
    ax.plot(b,sf,'.',alpha=0.1)
ax.set_xlim([0,4])
ax.set_ylim([0,1e-11])
# Out:
# (0.0, 1e-11)

# %%
fig, ax = plt.subplots()
for i in [0,10,50]:
    b = [x['baseline'] for x in data[i]['sf']]
    sf = [x['value'] for x in data[i]['sf']]
    ax.plot(b,sf,'.',alpha=0.1)
ax.set_xlim([0, 5])
ax.set_ylim([0,0.25e-10])
# Out:
# (0.0, 2.5e-11)
